# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 500)

# %%
df = pd.read_csv("meme kanseri data.csv")

# %%
def dataframe_ozet(df):
    print("🔹 İlk 5 Satır (df.head()):")
    print(df.head(), "\n")
    
    print("🔹 Son 5 Satır (df.tail()):")
    print(df.tail(), "\n")
    
    print(f"🔹 Şekil Bilgisi (df.shape): {df.shape} (Satır, Sütun)\n")
    
    print("🔹 Genel Bilgi (df.info()):")
    df.info()
    print()
    
    print(f"🔹 Sütun İsimleri (df.columns):\n{df.columns.tolist()}\n")
    
    print(f"🔹 İndeks Bilgisi (df.index):\n{df.index}\n")
    
    print("🔹 İstatistiksel Özet (df.describe().T):")
    print(df.describe().T, "\n")
    
    print(f"🔹 Eksik Veri Var mı? (df.isnull().values.any()): {df.isnull().values.any()}\n")
    
    print("🔹 Her Sütundaki Eksik Değer Sayısı (df.isnull().sum()):")
    print(df.isnull().sum())
dataframe_ozet(df)
# Out:
# 🔹 İlk 5 Satır (df.head()):
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  compactness_mean  concavity_mean  concave points_mean  symmetry_mean  fractal_dimension_mean  radius_se  texture_se  perimeter_se  area_se  smoothness_se  compactness_se  concavity_se  concave points_se  symmetry_se  fractal_dimension_se  radius_worst  texture_worst  perimeter_worst  area_worst  smoothness_worst  compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0    842302         M        17.99         10.38          122.80     1001.0          0.11840           0.27760          0.3001              0.14710         0.2419                 0.07871     1.0950      0.9053         8.589   153.40       0.006399         0.04904       0.05373            0.01587      0.03003              0.006193         25.38          17.33           184.60      2019.0            0.1622             0.6656           0.7119                0.2654          0.4601
# ...

# %%
df.drop("Unnamed: 32", axis=1, inplace=True)
df.drop("id", axis=1, inplace=True)

# %%
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  compactness_mean  concavity_mean  concave points_mean  symmetry_mean  fractal_dimension_mean  radius_se  texture_se  perimeter_se  area_se  smoothness_se  compactness_se  concavity_se  concave points_se  symmetry_se  fractal_dimension_se  radius_worst  texture_worst  perimeter_worst  area_worst  smoothness_worst  compactness_worst  concavity_worst  concave points_worst  symmetry_worst  fractal_dimension_worst
# 0         M        17.99         10.38          122.80     1001.0          0.11840           0.27760          0.3001              0.14710         0.2419                 0.07871     1.0950      0.9053         8.589   153.40       0.006399         0.04904       0.05373            0.01587      0.03003              0.006193         25.38          17.33           184.60      2019.0            0.1622             0.6656           0.7119                0.2654          0.4601                  0.11890
# ...

# %%
df = df.rename(columns={
    'id': 'id',
    'diagnosis': 'teşhis',
    'radius_mean': 'yarıçap_ort',
    'texture_mean': 'doku_ort',
    'perimeter_mean': 'çevre_ort',
    'area_mean': 'alan_ort',
    'smoothness_mean': 'düzgünlük_ort',
    'compactness_mean': 'sıklık_ort',
    'concavity_mean': 'çukur_ort',
    'concave points_mean': 'çukur_nokta_ort',
    'symmetry_mean': 'simetri_ort',
    'fractal_dimension_mean': 'fraktal_ort',
    
    'radius_se': 'yarıçap_sh',
    'texture_se': 'doku_sh',
    'perimeter_se': 'çevre_sh',
    'area_se': 'alan_sh',
    'smoothness_se': 'düzgünlük_sh',
    'compactness_se': 'sıklık_sh',
    'concavity_se': 'çukur_sh',
    'concave points_se': 'çukur_nokta_sh',
    'symmetry_se': 'simetri_sh',
    'fractal_dimension_se': 'fraktal_sh',
    
    'radius_worst': 'yarıçap_kötü',
    'texture_worst': 'doku_kötü',
    'perimeter_worst': 'çevre_kötü',
    'area_worst': 'alan_kötü',
    'smoothness_worst': 'düzgünlük_kötü',
    'compactness_worst': 'sıklık_kötü',
    'concavity_worst': 'çukur_kötü',
    'concave points_worst': 'çukur_nokta_kötü',
    'symmetry_worst': 'simetri_kötü',
    'fractal_dimension_worst': 'fraktal_kötü'
})

# %%
dataframe_ozet(df)
# Out:
# 🔹 İlk 5 Satır (df.head()):
#   teşhis  yarıçap_ort  doku_ort  çevre_ort  alan_ort  düzgünlük_ort  sıklık_ort  çukur_ort  çukur_nokta_ort  simetri_ort  fraktal_ort  yarıçap_sh  doku_sh  çevre_sh  alan_sh  düzgünlük_sh  sıklık_sh  çukur_sh  çukur_nokta_sh  simetri_sh  fraktal_sh  yarıçap_kötü  doku_kötü  çevre_kötü  alan_kötü  düzgünlük_kötü  sıklık_kötü  çukur_kötü  çukur_nokta_kötü  simetri_kötü  fraktal_kötü
# 0      M        17.99     10.38     122.80    1001.0        0.11840     0.27760     0.3001          0.14710       0.2419      0.07871      1.0950   0.9053     8.589   153.40      0.006399    0.04904   0.05373         0.01587     0.03003    0.006193         25.38      17.33      184.60     2019.0          0.1622       0.6656      0.7119            0.2654        0.4601       0.11890
# ...

# %%
df.to_csv('cleaned_cancer.csv',index=False)
